# %%
using Plots
using Statistics
using DataFrames
using CSV

# %%
df = CSV.read("AAPL Historical Data.csv", DataFrame)
# Out:
# 10690×7 DataFrame
#    Row │ Date        Price    Open     High     Low      Vol.     Change %
#        │ Date        Float64  Float64  Float64  Float64  String?  String
# ───────┼───────────────────────────────────────────────────────────────────
#      1 │ 1980-12-12     0.13     0.13     0.13     0.13  469.03M  -99.88%
#      2 │ 1980-12-15     0.12     0.12     0.12     0.12  175.88M  -7.69%
#      3 │ 1980-12-16     0.11     0.11     0.11     0.11  105.73M  -8.33%
#      4 │ 1980-12-17     0.12     0.12     0.12     0.12  86.44M   9.09%
#      5 │ 1980-12-18     0.12     0.12     0.12     0.12  73.45M   0.00%
#      6 │ 1980-12-19     0.13     0.13     0.13     0.13  48.63M   8.33%
#      7 │ 1980-12-22     0.13     0.13     0.13     0.13  37.36M   0.00%
#      8 │ 1980-12-23     0.14     0.14     0.14     0.14  46.95M   7.69%
#      9 │ 1980-12-24     0.15     0.15     0.15     0.15  48.00M   7.14%
#     10 │ 1980-12-26     0.16     0.16     0.16     0.16  55.57M   6.67%
# ...

# %%
plot(df[!,:Price], label = "Price")
plot!(df[!,:Open], label = "Open")

# %%
using StatsPlots
violin(df[!,"Open"], alpha = 0.7, label = "Open stocks distribution")

# %%
violin(df[!,"High"], alpha = 1, label = "High stocks distribution")
violin!(df[!,"Low"], alpha = 0.9, label = "Low stocks distribution")

# %%
histogram(df[!,:"High"], label = "High stocks histogram")

# %%
scatter(df[!,"Low"],alpha = 0.8, markerstrokewidth = 0.5, markersize = 2)

# %%
plot(df["High"], y=:High, kind = "box")
# Out:
# ArgumentError: syntax df[column] is not supported use df[!, column] instead
#
# Stacktrace:
#  [1] getindex(#unused#::DataFrame, #unused#::String)
#    @ DataFrames C:\Users\Hp\.julia\packages\DataFrames\dgZn3\src\abstractdataframe\abstractdataframe.jl:2595
#  [2] top-level scope
#    @ In[58]:1
