# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import igraph as ig

# %%
df = pd.read_csv("airports.csv")

# %%
df
# Out:
#     IATA                              AIRPORT                            CITY  \
# 0    ABQ            Albuquerque International                     Albuquerque
# 1    ANC  Ted Stevens Anchorage International                       Anchorage
# 2    ATL    William B Hartsfield-Atlanta Intl                         Atlanta
# 3    AUS       Austin-Bergstrom International                          Austin
# 4    BDL                Bradley International                   Windsor Locks
# ..   ...                                  ...                             ...
# 336  WRG                             Wrangell                        Wrangell
# 337  WYS                          Yellowstone                West Yellowstone
# 338  XNA          Northwest Arkansas Regional  Fayetteville Springdale Rogers
# 339  YAK                              Yakutat                         Yakutat
# 340  YUM         Yuma MCAS-Yuma International                            Yuma
#
# ...

# %%
df.drop(labels = "COUNTRY", axis = 1)
# Out:
#     IATA                              AIRPORT                            CITY  \
# 0    ABQ            Albuquerque International                     Albuquerque
# 1    ANC  Ted Stevens Anchorage International                       Anchorage
# 2    ATL    William B Hartsfield-Atlanta Intl                         Atlanta
# 3    AUS       Austin-Bergstrom International                          Austin
# 4    BDL                Bradley International                   Windsor Locks
# ..   ...                                  ...                             ...
# 336  WRG                             Wrangell                        Wrangell
# 337  WYS                          Yellowstone                West Yellowstone
# 338  XNA          Northwest Arkansas Regional  Fayetteville Springdale Rogers
# 339  YAK                              Yakutat                         Yakutat
# 340  YUM         Yuma MCAS-Yuma International                            Yuma
#
#     STATE   LATITUDE   LONGITUDE
# ...

# %%
df.drop(labels = "IATA", axis = 1)
# Out:
#                                  AIRPORT                            CITY  \
# 0              Albuquerque International                     Albuquerque
# 1    Ted Stevens Anchorage International                       Anchorage
# 2      William B Hartsfield-Atlanta Intl                         Atlanta
# 3         Austin-Bergstrom International                          Austin
# 4                  Bradley International                   Windsor Locks
# ..                                   ...                             ...
# 336                             Wrangell                        Wrangell
# 337                          Yellowstone                West Yellowstone
# 338          Northwest Arkansas Regional  Fayetteville Springdale Rogers
# 339                              Yakutat                         Yakutat
# 340         Yuma MCAS-Yuma International                            Yuma
#
#     STATE COUNTRY   LATITUDE   LONGITUDE
# 0      NM     USA  35.040222 -106.609194
# ...

# %%
A = np.array(df["LATITUDE"])
B = np.array(df["LONGITUDE"])

# %%
A1 = A.astype(object)

# %%
B1 = B.astype(object)

# %%
C = np.concatenate([A,B])

# %%
print(C)
# Out:
# [  35.04022222   61.17432028   33.64044444   30.19453278   41.93887417
#    33.56294306   36.12447667   42.3643475    42.94052472   34.20061917
#    39.17540167   32.89864639   41.41089417   35.21401111   39.99798528
#    39.04614278   32.84711389   38.85208333   39.85840806   32.89595056
#    42.21205889   31.80666667   40.69249722   26.07258333   21.31869111
#    29.64541861   38.94453194   29.98047222   39.71732917   30.49405556
#    40.63975111   36.08036111   33.94253611   40.77724306   34.72939611
#    39.29760528   28.42888889   41.7859825    35.04241667   25.79325
#    42.94722222   44.88054694   29.99338889   37.72129083   20.89864972
#    35.39308833   41.30251861   34.056        41.979595     36.89461111
#    26.68316194   45.58872222   39.87195278   33.43416667   40.49146583
#    41.72399917   35.87763889   37.50516667   39.49857611   26.53616667
#    32.73355611   29.53369444   38.17438889   47.44898194   37.61900194
# ...

# %%
d1 = np.array_split(A,341)

# %%
print(d1)
# Out:
# [array([35.04022222]), array([61.17432028]), array([33.64044444]), array([30.19453278]), array([41.93887417]), array([33.56294306]), array([36.12447667]), array([42.3643475]), array([42.94052472]), array([34.20061917]), array([39.17540167]), array([32.89864639]), array([41.41089417]), array([35.21401111]), array([39.99798528]), array([39.04614278]), array([32.84711389]), array([38.85208333]), array([39.85840806]), array([32.89595056]), array([42.21205889]), array([31.80666667]), array([40.69249722]), array([26.07258333]), array([21.31869111]), array([29.64541861]), array([38.94453194]), array([29.98047222]), array([39.71732917]), array([30.49405556]), array([40.63975111]), array([36.08036111]), array([33.94253611]), array([40.77724306]), array([34.72939611]), array([39.29760528]), array([28.42888889]), array([41.7859825]), array([35.04241667]), array([25.79325]), array([42.94722222]), array([44.88054694]), array([29.99338889]), array([37.72129083]), array([20.89864972]), array([35.39
# ...

# %%
d2 = np.array_split(B,341)
print(d2)
# Out:
# [array([-106.6091944]), array([-149.9961856]), array([-84.42694444]), array([-97.66987194]), array([-72.68322833]), array([-86.75354972]), array([-86.67818222]), array([-71.00517917]), array([-78.73216667]), array([-118.3584969]), array([-76.66819833]), array([-80.04050583]), array([-81.84939667]), array([-80.94312583]), array([-82.89188278]), array([-84.6621725]), array([-96.85177222]), array([-77.03772222]), array([-104.6670019]), array([-97.0372]), array([-83.34883583]), array([-106.3778056]), array([-74.16866056]), array([-80.15275]), array([-157.9224072]), array([-95.27888889]), array([-77.45580972]), array([-95.33972222]), array([-86.29438417]), array([-81.68786111]), array([-73.77892556]), array([-115.1523333]), array([-118.4080744]), array([-73.87260917]), array([-92.22424556]), array([-94.71390556]), array([-81.31602778]), array([-87.75242444]), array([-89.97666667]), array([-80.29055556]), array([-87.89658333]), array([-93.2169225]), array([-90.25802778]), array([-122.22071
# ...

# %%
d3 = np.concatenate((d1,d2),axis = 1)

# %%
print(d3)
# Out:
# [[  35.04022222 -106.6091944 ]
#  [  61.17432028 -149.9961856 ]
#  [  33.64044444  -84.42694444]
#  [  30.19453278  -97.66987194]
#  [  41.93887417  -72.68322833]
#  [  33.56294306  -86.75354972]
#  [  36.12447667  -86.67818222]
#  [  42.3643475   -71.00517917]
#  [  42.94052472  -78.73216667]
#  [  34.20061917 -118.3584969 ]
#  [  39.17540167  -76.66819833]
#  [  32.89864639  -80.04050583]
#  [  41.41089417  -81.84939667]
#  [  35.21401111  -80.94312583]
#  [  39.99798528  -82.89188278]
#  [  39.04614278  -84.6621725 ]
#  [  32.84711389  -96.85177222]
#  [  38.85208333  -77.03772222]
#  [  39.85840806 -104.6670019 ]
#  [  32.89595056  -97.0372    ]
#  [  42.21205889  -83.34883583]
#  [  31.80666667 -106.3778056 ]
#  [  40.69249722  -74.16866056]
#  [  26.07258333  -80.15275   ]
#  [  21.31869111 -157.9224072 ]
#  [  29.64541861  -95.27888889]
#  [  38.94453194  -77.45580972]
#  [  29.98047222  -95.33972222]
#  [  39.71732917  -86.29438417]
#  [  30.49405556  -81.68786111]
# ...

# %%
M = np.hsplit(d3,1)

# %%
print(M)
# Out:
# [array([[  35.04022222, -106.6091944 ],
#        [  61.17432028, -149.9961856 ],
#        [  33.64044444,  -84.42694444],
#        [  30.19453278,  -97.66987194],
#        [  41.93887417,  -72.68322833],
#        [  33.56294306,  -86.75354972],
#        [  36.12447667,  -86.67818222],
#        [  42.3643475 ,  -71.00517917],
#        [  42.94052472,  -78.73216667],
#        [  34.20061917, -118.3584969 ],
#        [  39.17540167,  -76.66819833],
#        [  32.89864639,  -80.04050583],
#        [  41.41089417,  -81.84939667],
#        [  35.21401111,  -80.94312583],
#        [  39.99798528,  -82.89188278],
#        [  39.04614278,  -84.6621725 ],
#        [  32.84711389,  -96.85177222],
#        [  38.85208333,  -77.03772222],
#        [  39.85840806, -104.6670019 ],
#        [  32.89595056,  -97.0372    ],
#        [  42.21205889,  -83.34883583],
#        [  31.80666667, -106.3778056 ],
#        [  40.69249722,  -74.16866056],
#        [  26.07258333,  -80.15275   ],
# ...

# %%
M5 = np.array(M)
print(M5)
# Out:
# [[[  35.04022222 -106.6091944 ]
#   [  61.17432028 -149.9961856 ]
#   [  33.64044444  -84.42694444]
#   [  30.19453278  -97.66987194]
#   [  41.93887417  -72.68322833]
#   [  33.56294306  -86.75354972]
#   [  36.12447667  -86.67818222]
#   [  42.3643475   -71.00517917]
#   [  42.94052472  -78.73216667]
#   [  34.20061917 -118.3584969 ]
#   [  39.17540167  -76.66819833]
#   [  32.89864639  -80.04050583]
#   [  41.41089417  -81.84939667]
#   [  35.21401111  -80.94312583]
#   [  39.99798528  -82.89188278]
#   [  39.04614278  -84.6621725 ]
#   [  32.84711389  -96.85177222]
#   [  38.85208333  -77.03772222]
#   [  39.85840806 -104.6670019 ]
#   [  32.89595056  -97.0372    ]
#   [  42.21205889  -83.34883583]
#   [  31.80666667 -106.3778056 ]
#   [  40.69249722  -74.16866056]
#   [  26.07258333  -80.15275   ]
#   [  21.31869111 -157.9224072 ]
#   [  29.64541861  -95.27888889]
#   [  38.94453194  -77.45580972]
#   [  29.98047222  -95.33972222]
#   [  39.71732917  -86.29438417]
# ...

# %%
D = dict(enumerate(M5.flatten(),1))

# %%
D
# Out:
# {1: 35.04022222,
#  2: -106.6091944,
#  3: 61.17432028,
#  4: -149.9961856,
#  5: 33.64044444,
#  6: -84.42694444,
#  7: 30.19453278,
#  8: -97.66987194,
#  9: 41.93887417,
#  10: -72.68322833,
#  11: 33.56294306,
#  12: -86.75354972,
#  13: 36.12447667,
#  14: -86.67818222,
#  15: 42.3643475,
#  16: -71.00517917,
#  17: 42.94052472,
#  18: -78.73216667,
#  19: 34.20061917,
#  20: -118.3584969,
#  21: 39.17540167,
#  22: -76.66819833,
#  23: 32.89864639,
#  24: -80.04050583,
#  25: 41.41089417,
#  26: -81.84939667,
#  27: 35.21401111,
#  28: -80.94312583,
#  29: 39.99798528,
#  30: -82.89188278,
#  31: 39.04614278,
#  32: -84.6621725,
#  33: 32.84711389,
#  34: -96.85177222,
#  35: 38.85208333,
#  36: -77.03772222,
#  37: 39.85840806,
#  38: -104.6670019,
#  39: 32.89595056,
#  40: -97.0372,
#  41: 42.21205889,
#  42: -83.34883583,
#  43: 31.80666667,
#  44: -106.3778056,
#  45: 40.69249722,
#  46: -74.16866056,
#  47: 26.07258333,
#  48: -80.15275,
#  49: 21.31869111,
# ...

# %%
import networkx as nx

# %%
g = networkx.Graph()

# %%
for i in D:
    g.add_node(i)

# %%
print(g)
# Out:
# Graph with 682 nodes and 0 edges
